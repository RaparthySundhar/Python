# %%
import pandas as pd

# %%
students_data=pd.read_csv(r"C:\Users\saisu\Downloads\StudentsPerformance.csv")

# %%
students_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #  1) Creating Percentage Based On Math Score, Reading Score And Writing Score

# %%
students_data["percentage"]=students_data["math score"]+students_data["reading score"]+students_data["writing score"]/300*100

# %%
students_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # 2) Takeout All The Male Whose Percentage Is > 50%

# %%
students_data.loc[(students_data["percentage"]>50) & (students_data["gender"]=="male")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %% [markdown]
# #  3) Takeout All The Male Whose Percentage Is < 50%

# %%
students_data.loc[(students_data["percentage"]<50) & (students_data["gender"]=="male")]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, percentage]
# Index: []

# %% [markdown]
# #  4) Takeout All The Female Whose Percentage Is > 50%

# %%
students_data.loc[(students_data["percentage"]>50) & (students_data["gender"]=="female")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #  5) Takeout All The Female Whose Percentage Is < 50%

# %%
students_data.loc[(students_data["percentage"]<50) & (students_data["gender"]=="female")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
#
#      percentage
# 59    20.333333
# 980   39.666667

# %% [markdown]
# # 6) Total Number Of Male's

# %%
m=len(students_data.loc[students_data["gender"]=="male"])
print("Total Number Of Male's In The Table Is :-",m)
# Out:
# Total Number Of Male's In The Table Is :- 482

# %% [markdown]
# # 7) Total Number Of Female's

# %%
f=len(students_data.loc[students_data["gender"]=="female"])
print("Total Number Of Female's In The Table Is :-",f)
# Out:
# Total Number Of Female's In The Table Is :- 518

# %% [markdown]
# # 8) Students Parent Education Level Is Bachelor's Degree

# %%
parent_edc_level=students_data.loc[students_data["parental level of education"]=="bachelor's degree"]

# %%
parent_edc_level
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
print("Students Parent Education Level Is Bachelor's Degree Is :-",len(parent_edc_level))
# Out:
# Students Parent Education Level Is Bachelor's Degree Is :- 118

# %% [markdown]
# # 9) Male In Standard Launch

# %%
male_stnd_lunch=students_data.loc[(students_data["lunch"]=="standard") & (students_data["gender"]=="male")]

# %%
male_stnd_lunch
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %%
print("Male In Standard Launch Is :-",len(male_stnd_lunch))
# Out:
# Male In Standard Launch Is :- 316

# %% [markdown]
# # Male In Free/Reduced Lunch

# %%
male_free_lunch=students_data.loc[(students_data["lunch"]=="free/reduced") & (students_data["gender"]=="male")]

# %%
male_free_lunch
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
# ..     ...            ...                         ...           ...
# 943   male        group A            some high school  free/reduced
# 948   male        group B            some high school  free/reduced
# 976   male        group B                some college  free/reduced
# 990   male        group E                 high school  free/reduced
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
print("Male In Male In Free/Reduced Lunch Launch Is :-",len(male_free_lunch))
# Out:
# Male In Male In Free/Reduced Lunch Launch Is :- 166

# %% [markdown]
# # 10) Female In Standard Launch

# %%
female_stnd_lunch=students_data.loc[(students_data["lunch"]=="standard") & (students_data["gender"]=="female")]

# %%
female_stnd_lunch
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
print("Female In Standard Launch Is :-",len(female_stnd_lunch))
# Out:
# Female In Standard Launch Is :- 329

# %% [markdown]
# # Female In Free/Reduced Lunch

# %%
female_free_lunch=students_data.loc[(students_data["lunch"]=="free/reduced") & (students_data["gender"]=="female")]

# %%
female_free_lunch
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 32   female        group E             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
print("Female In Male In Free/Reduced Lunch Launch Is :-",len(female_free_lunch))
# Out:
# Female In Male In Free/Reduced Lunch Launch Is :- 189
